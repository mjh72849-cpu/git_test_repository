# %%
import math

# %%
print('hello')

# %%
def ok(r,c):
    if r>=n or c>=n:
        return False
    if r==n-1 and c==n-1:
        return True
    if lst[r][c]==1:
        return False
    return ok(r+1,c) or ok(r,c+1)
n=int(input())
lst=[list(map(int,input().split())) for i in range(n)]
if ok(0,0):
    print('Yes')
else:
    print('No')
